# %% [markdown]
# <a href="https://colab.research.google.com/github/Suyoung-Min/Pytorch-Tutorial/blob/main/Tutorial/miniBatchDataLoad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader

# %%
x_train  =  torch.FloatTensor([[73,  80,  75], 
                               [93,  88,  93], 
                               [89,  91,  90], 
                               [96,  98,  100],   
                               [73,  66,  70]])  
y_train  =  torch.FloatTensor([[152],  [185],  [180],  [196],  [142]])

dataset = TensorDataset(x_train,y_train)

# %%
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)

# %%
model = nn.Linear(3,1)
optimizer = torch.optim.SGD(model.parameters(),lr = 1e-5)

# %%
nb_epochs = 2000
for epoch in range(nb_epochs+1):
  for batch_idx, samples in enumerate(dataloader):

    x_train, y_train = samples

    prediction = model(x_train)

    cost = F.mse_loss(prediction, y_train)

    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    
    print('Epoch {:4d}/{} Batch {}/{} Cost: {:.6f}'.format(
        epoch, nb_epochs, batch_idx+1, len(dataloader),
        cost.item()
        ))
    
  if epoch % 100 == 0:
    print(f'Epoch {epoch} Cost: {cost} ')
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Epoch  340/2000 Batch 1/3 Cost: 0.743986
# Epoch  340/2000 Batch 2/3 Cost: 2.628040
# Epoch  340/2000 Batch 3/3 Cost: 6.714248
# Epoch  341/2000 Batch 1/3 Cost: 1.467753
# Epoch  341/2000 Batch 2/3 Cost: 3.287419
# Epoch  341/2000 Batch 3/3 Cost: 5.391996
# Epoch  342/2000 Batch 1/3 Cost: 1.550287
# Epoch  342/2000 Batch 2/3 Cost: 3.749517
# Epoch  342/2000 Batch 3/3 Cost: 0.247306
# Epoch  343/2000 Batch 1/3 Cost: 4.160088
# Epoch  343/2000 Batch 2/3 Cost: 3.256829
# Epoch  343/2000 Batch 3/3 Cost: 0.069314
# Epoch  344/2000 Batch 1/3 Cost: 1.478401
# Epoch  344/2000 Batch 2/3 Cost: 3.734344
# Epoch  344/2000 Batch 3/3 Cost: 0.256527
# Epoch  345/2000 Batch 1/3 Cost: 3.070293
# Epoch  345/2000 Batch 2/3 Cost: 1.049616
# Epoch  345/2000 Batch 3/3 Cost: 2.919585
# Epoch  346/2000 Batch 1/3 Cost: 5.921120
# Epoch  346/2000 Batch 2/3 Cost: 2.287327
# Epoch  346/2000 Batch 3/3 Cost: 0.021866
# Epoch  347/2000 Batch 1/3 Cost: 5.103329
# ...

# %%
new_var = torch.FloatTensor([73,80,75])

pred_y = model(new_var)
print(pred_y)
# Out:
# tensor([151.4794], grad_fn=<AddBackward0>)
